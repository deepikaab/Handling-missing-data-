# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files
rawdata = files.upload()
rawdata
# Out:
#      <input type="file" id="files-e182fd0d-ecfc-4374-b521-d230619ced59" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e182fd0d-ecfc-4374-b521-d230619ced59">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv("loan_small_w2 (1) (1).csv")
df
# Out:
#      Loan_ID  Gender  ApplicantIncome  CoapplicantIncome  LoanAmount   Area  \
# 0   LP001002     NaN           5849.0                0.0         NaN  urban
# 1   LP001003    Male           4583.0                NaN       128.0   semi
# 2   LP001005    Male           3000.0                0.0        66.0    NaN
# 3   LP001006  Female           2583.0             2358.0       120.0   semi
# 4   LP001008    Male              NaN                0.0       141.0  urban
# 5   LP001011    Male           5417.0             4196.0       267.0   semi
# 6   LP001013    Male           2333.0             1516.0         NaN  rural
# 7   LP001014  Female           3036.0             2504.0       158.0   semi
# 8   LP001018    Male           4006.0             1526.0       168.0  rural
# 9   LP001020    Male          12841.0            10968.0       349.0   semi
# 10  LP001024  Female           3200.0              700.0        70.0  urban
# ...

# %%
x = df.iloc[:,0:6].values
x
# Out:
# array([['LP001002', nan, 5849.0, 0.0, nan, 'urban'],
#        ['LP001003', 'Male', 4583.0, nan, 128.0, 'semi'],
#        ['LP001005', 'Male', 3000.0, 0.0, 66.0, nan],
#        ['LP001006', 'Female', 2583.0, 2358.0, 120.0, 'semi'],
#        ['LP001008', 'Male', nan, 0.0, 141.0, 'urban'],
#        ['LP001011', 'Male', 5417.0, 4196.0, 267.0, 'semi'],
#        ['LP001013', 'Male', 2333.0, 1516.0, nan, 'rural'],
#        ['LP001014', 'Female', 3036.0, 2504.0, 158.0, 'semi'],
#        ['LP001018', 'Male', 4006.0, 1526.0, 168.0, 'rural'],
#        ['LP001020', 'Male', 12841.0, 10968.0, 349.0, 'semi'],
#        ['LP001024', 'Female', 3200.0, 700.0, 70.0, 'urban'],
#        ['LP001027', 'Male', 2500.0, 1840.0, 109.0, 'urban'],
#        ['LP001028', 'Female', nan, 8106.0, nan, 'urban'],
#        ['LP001029', 'Male', 1853.0, 2840.0, 114.0, 'urban'],
#        ['LP001030', 'Male', 1299.0, 1086.0, 17.0, 'semi'],
#        ['LP001032', 'Male', 4950.0, 0.0, 125.0, 'semi']], dtype=object)

# %%
df.isnull().sum()
# Out:
# Loan_ID              0
# Gender               1
# ApplicantIncome      2
# CoapplicantIncome    1
# LoanAmount           3
# Area                 1
# Loan_Status          1
# dtype: int64

# %%
df.dropna(subset = ["Loan_Status"])
# Out:
#      Loan_ID  Gender  ApplicantIncome  CoapplicantIncome  LoanAmount   Area  \
# 0   LP001002     NaN           5849.0                0.0         NaN  urban
# 1   LP001003    Male           4583.0                NaN       128.0   semi
# 2   LP001005    Male           3000.0                0.0        66.0    NaN
# 4   LP001008    Male              NaN                0.0       141.0  urban
# 5   LP001011    Male           5417.0             4196.0       267.0   semi
# 6   LP001013    Male           2333.0             1516.0         NaN  rural
# 7   LP001014  Female           3036.0             2504.0       158.0   semi
# 8   LP001018    Male           4006.0             1526.0       168.0  rural
# 9   LP001020    Male          12841.0            10968.0       349.0   semi
# 10  LP001024  Female           3200.0              700.0        70.0  urban
# 11  LP001027    Male           2500.0             1840.0       109.0  urban
# ...

# %%
dt = df.copy()
cols = ["ApplicantIncome","CoapplicantIncome","LoanAmount"]

# %%
df = df.fillna(value = dt[cols].mean())
df
# Out:
#      Loan_ID  Gender  ApplicantIncome  CoapplicantIncome  LoanAmount   Area  \
# 0   LP001002     NaN      5849.000000           0.000000  140.923077  urban
# 1   LP001003    Male      4583.000000        2509.333333  128.000000   semi
# 2   LP001005    Male      3000.000000           0.000000   66.000000    NaN
# 3   LP001006  Female      2583.000000        2358.000000  120.000000   semi
# 4   LP001008    Male      4103.571429           0.000000  141.000000  urban
# 5   LP001011    Male      5417.000000        4196.000000  267.000000   semi
# 6   LP001013    Male      2333.000000        1516.000000  140.923077  rural
# 7   LP001014  Female      3036.000000        2504.000000  158.000000   semi
# 8   LP001018    Male      4006.000000        1526.000000  168.000000  rural
# 9   LP001020    Male     12841.000000       10968.000000  349.000000   semi
# 10  LP001024  Female      3200.000000         700.000000   70.000000  urban
# ...

# %%
df.isnull().sum()
# Out:
# Loan_ID              0
# Gender               1
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Area                 1
# Loan_Status          1
# dtype: int64

# %%
ro = ["Gender","Area","Loan_Status"]
df = df.fillna(value = dt[ro].mode().iloc[0])
df
# Out:
#      Loan_ID  Gender  ApplicantIncome  CoapplicantIncome  LoanAmount   Area  \
# 0   LP001002    Male      5849.000000           0.000000  140.923077  urban
# 1   LP001003    Male      4583.000000        2509.333333  128.000000   semi
# 2   LP001005    Male      3000.000000           0.000000   66.000000   semi
# 3   LP001006  Female      2583.000000        2358.000000  120.000000   semi
# 4   LP001008    Male      4103.571429           0.000000  141.000000  urban
# 5   LP001011    Male      5417.000000        4196.000000  267.000000   semi
# 6   LP001013    Male      2333.000000        1516.000000  140.923077  rural
# 7   LP001014  Female      3036.000000        2504.000000  158.000000   semi
# 8   LP001018    Male      4006.000000        1526.000000  168.000000  rural
# 9   LP001020    Male     12841.000000       10968.000000  349.000000   semi
# 10  LP001024  Female      3200.000000         700.000000   70.000000  urban
# ...

# %%
df.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Area                 0
# Loan_Status          0
# dtype: int64
